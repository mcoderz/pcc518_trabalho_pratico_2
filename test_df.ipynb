# %%
import pandas as pd

# %%
caminho_df_test = 'data_test.csv'
caminho_df_training = 'data_training.csv'

df_test = pd.read_csv(caminho_df_test)
df_training = pd.read_csv(caminho_df_training)

# %%
pd.options.display.max_rows=1000

# %%
df1=df_test.groupby('topico').count()

df2=df_training.groupby('topico').count()

# %%
df1.merge(df2, on=['topico'], how='outer', suffixes=['', '_'], indicator=True)
# Out:
#                  dado  arquivo  texto  origem  arquivo_  texto_ _merge
# topico
# acq               719      719    719    1650      1650    1650   both
# alum               23       23     23      35        35      35   both
# barley             14       14     14      37        37      37   both
# bop                30       30     30      75        75      75   both
# carcass            18       18     18      50        50      50   both
# castor-oil          1        1      1       1         1       1   both
# cocoa              18       18     18      55        55      55   both
# coconut             2        2      2       4         4       4   both
# coconut-oil         3        3      3       4         4       4   both
# coffee             28       28     28     111       111     111   both
# copper             18       18     18      47        47      47   both
# copra-cake          1        1      1       2         2       2   both
# ...
